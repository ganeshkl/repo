# %%
import csv
import json

# The given JSON data
data = [
    {
        "id": 1,
        "name": "Schoen - Feeney",
        "address": "8017 Joseph Creek",
        "zip": "83193",
        "country": "Sri Lanka",
        "employeeCount": 2252,
        "industry": "Technology",
        "marketCap": 4612673628,
        "domain": "joyous-coal.com",
        "logo": "https://example.com/logo1.png",
        "ceoName": "Isadore Runte"
    },
    {
        "id": 2,
        "name": "Torp LLC",
        "address": "73776 Waterloo Road",
        "zip": "02467-1718",
        "country": "Paraguay",
        "employeeCount": 1779,
        "industry": "Technology",
        "marketCap": 7874363038,
        "domain": "unaware-chemistry.info",
        "logo": "https://example.com/logo1.png",
        "ceoName": "Mayra Sporer"
    },
    {
        "id": 3,
        "name": "Keebler, Collier and Little",
        "address": "39502 Kuphal Forest",
        "zip": "92765",
        "country": "Haiti",
        "employeeCount": 1192,
        "industry": "Technology",
        "marketCap": 311624957,
        "domain": "jolly-space.name",
        "logo": "https://example.com/logo1.png",
        "ceoName": "Carolyne Gleason"
    },
    {
        "id": 4,
        "name": "Grant Inc",
        "address": "2152 Green Street",
        "zip": "16100-3970",
        "country": "Cayman Islands",
        "employeeCount": 5292,
        "industry": "Technology",
        "marketCap": 6503831063,
        "domain": "anguished-dealer.name",
        "logo": "https://example.com/logo1.png",
        "ceoName": "Amiya Marquardt"
    },
    {
        "id": 4,
        "name": "Altenwerth - Denesik",
        "address": "422 Herzog Fields",
        "zip": "67395",
        "country": "British Indian Ocean Territory (Chagos Archipelago)",
        "employeeCount": 7335,
        "industry": "Technology",
        "marketCap": 2197211251,
        "domain": "suspicious-transportation.info",
        "logo": "https://example.com/logo1.png",
        "ceoName": "Arvel Thompson"
    },
    {
        "id": 5,
        "name": "Witting - Howell",
        "address": "96162 Deckow Lane",
        "zip": "35525",
        "country": "Bosnia and Herzegovina",
        "employeeCount": 9610,
        "industry": "Technology",
        "marketCap": 3774866120,
        "domain": "regal-lip.org",
        "logo": "https://example.com/logo1.png",
        "ceoName": "Annamae Brekke"
    },
    {
        "id": 6,
        "name": "West - Heaney",
        "address": "82602 Walter Radial",
        "zip": "35502",
        "country": "Belarus",
        "employeeCount": 2532,
        "industry": "Technology",
        "marketCap": 5145361638,
        "domain": "young-neuron.info",
        "logo": "https://example.com/logo1.png",
        "ceoName": "Allen Bernier"
    },
    {
        "id": 7,
        "name": "Doyle, Price and Lynch",
        "address": "27569 Dooley Extensions",
        "zip": "77374-2748",
        "country": "Cameroon",
        "employeeCount": 8143,
        "industry": "Technology",
        "marketCap": 9243492284,
        "domain": "upbeat-estate.net",
        "logo": "https://example.com/logo1.png",
        "ceoName": "John Skiles"
    },
    {
        "id": 8,
        "name": "Kertzmann Inc",
        "address": "287 Torp Bypass",
        "zip": "24018",
        "country": "Thailand",
        "employeeCount": 593,
        "industry": "Technology",
        "marketCap": 8917834250,
        "domain": "altruistic-shoemaker.com",
        "logo": "https://example.com/logo1.png",
        "ceoName": "Domenico Fay"
    },
    {
        "id": 9,
        "name": "Kutch - Kling",
        "address": "676 Roman Road",
        "zip": "08476-2389",
        "country": "Sweden",
        "employeeCount": 9143,
        "industry": "Technology",
        "marketCap": 240576928,
        "domain": "infamous-pseudoscience.com",
        "logo": "https://example.com/logo1.png",
        "ceoName": "Flavio Bauch"
    },
    {
        "id": 10,
        "name": "Bednar - Lueilwitz",
        "address": "355 Fritsch Corners",
        "zip": "14948-5651",
        "country": "Chile",
        "employeeCount": 6117,
        "industry": "Technology",
        "marketCap": 8981794692,
        "domain": "friendly-suspension.info",
        "logo": "https://example.com/logo1.png",
        "ceoName": "Santa Jacobi"
    }
]

# Define the header for the CSV file
header = ["id", "name", "address", "zip", "country", "employeeCount", "industry", "marketCap", "domain", "logo", "ceoName"]

# Open a CSV file to write the data
with open("companies.csv", mode="w", newline="") as file:
    writer = csv.DictWriter(file, fieldnames=header)
    writer.writeheader()
    writer.writerows(data)

print("CSV file created successfully!")
# Out:
# CSV file created successfully!
